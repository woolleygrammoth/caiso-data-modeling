# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime, os
from prophet import Prophet

# %%
hist = pd.read_csv('./scraped-data/caiso-net-demand.csv')
hist.index = pd.to_datetime(hist['Timestamp'])
hist.drop('Timestamp', axis=1, inplace=True)
hist
# Out:
#                      Hour-ahead forecast   Demand  Net demand
# Timestamp
# 2018-04-10 00:00:00              22701.0  22459.0     22117.0
# 2018-04-10 00:05:00              22311.0  22371.0     21955.0
# 2018-04-10 00:10:00              22311.0  22330.0     21882.0
# 2018-04-10 00:15:00              22311.0  22082.0     21774.0
# 2018-04-10 00:20:00              22094.0  21978.0     21613.0
# ...                                  ...      ...         ...
# 2022-06-02 23:35:00              25260.0  25646.0     20660.0
# 2022-06-02 23:40:00              25260.0  25495.0     20522.0
# 2022-06-02 23:45:00              25260.0  25339.0     20378.0
# 2022-06-02 23:50:00              24892.0  25201.0     20273.0
# 2022-06-02 23:55:00              24892.0  25059.0     20141.0
#
# [436320 rows x 3 columns]

# %%
# Data cleaning
for col in hist.columns: 
    print(col, hist[col].isna().sum())
    print(hist[hist[col].isna()])
# Out:
# Hour-ahead forecast 324
#                      Hour-ahead forecast  Demand  Net demand
# Timestamp
# 2019-03-10 02:00:00                  NaN     NaN         NaN
# 2019-03-10 02:05:00                  NaN     NaN         NaN
# 2019-03-10 02:10:00                  NaN     NaN         NaN
# 2019-03-10 02:15:00                  NaN     NaN         NaN
# 2019-03-10 02:20:00                  NaN     NaN         NaN
# ...                                  ...     ...         ...
# 2021-03-14 02:35:00                  NaN     NaN         NaN
# 2021-03-14 02:40:00                  NaN     NaN         NaN
# 2021-03-14 02:45:00                  NaN     NaN         NaN
# 2021-03-14 02:50:00                  NaN     NaN         NaN
# 2021-03-14 02:55:00                  NaN     NaN         NaN
#
# [324 rows x 3 columns]
# Demand 268
#                      Hour-ahead forecast  Demand  Net demand
# Timestamp
# 2018-04-11 07:40:00              24854.0     NaN         NaN
# 2018-04-11 07:45:00              24854.0     NaN         NaN
# 2018-04-11 07:50:00              24874.0     NaN         NaN
# 2018-04-11 07:55:00              24874.0     NaN         NaN
# 2018-04-11 08:00:00              24874.0     NaN         NaN
# ...                                  ...     ...         ...
# 2022-05-18 23:55:00              24727.0     NaN         NaN
# 2022-05-19 23:50:00              24098.0     NaN         NaN
# 2022-05-19 23:55:00              24098.0     NaN         NaN
# 2022-05-20 23:50:00              24098.0     NaN         NaN
# 2022-05-20 23:55:00              24098.0     NaN         NaN
#
# [268 rows x 3 columns]
# Net demand 1996
#                      Hour-ahead forecast  Demand  Net demand
# Timestamp
# 2018-04-11 07:40:00              24854.0     NaN         NaN
# 2018-04-11 07:45:00              24854.0     NaN         NaN
# 2018-04-11 07:50:00              24874.0     NaN         NaN
# 2018-04-11 07:55:00              24874.0     NaN         NaN
# 2018-04-11 08:00:00              24874.0     NaN         NaN
# ...                                  ...     ...         ...
# 2022-05-18 23:55:00              24727.0     NaN         NaN
# 2022-05-19 23:50:00              24098.0     NaN         NaN
# 2022-05-19 23:55:00              24098.0     NaN         NaN
# 2022-05-20 23:50:00              24098.0     NaN         NaN
# 2022-05-20 23:55:00              24098.0     NaN         NaN
#
# [1996 rows x 3 columns]

# %%
df_clean = df.interpolate(method='linear')
df_clean = df_clean.resample('7D').mean()

plt.plot(df_clean.index, df_clean['Net demand'])
plt.show()

# %%
from prophet import Prophet

# use hourly average data as input to forecasting model
hourly = hist.resample('H').mean()
ds, y = hourly.index, hourly['Net demand']


hist_bare = pd.DataFrame({'ds': ds, 'y': y})
hist_bare.reset_index(inplace=True)
hist_bare.drop('Timestamp', inplace=True, axis=1)

m = Prophet()
m.fit(hist_bare)

# %%
future = m.make_future_dataframe(periods=4*8760, freq='H', include_history=True)
forecast = m.predict(future)

# %%
from prophet.plot import plot_plotly, plot_components_plotly


#### restart kernel and make these plots
plot_plotly(m, forecast)
plot_components_plotly(m, forecast)


# m.plot(forecast)
# m.plot_components(forecast)

# %%
hist_bare
# Out:
#                        ds             y
# 0     2018-04-10 00:00:00  21469.916667
# 1     2018-04-10 01:00:00  20404.500000
# 2     2018-04-10 02:00:00  19612.333333
# 3     2018-04-10 03:00:00  19084.166667
# 4     2018-04-10 04:00:00  19235.916667
# ...                   ...           ...
# 36355 2022-06-02 19:00:00  24945.500000
# 36356 2022-06-02 20:00:00  25482.000000
# 36357 2022-06-02 21:00:00  24624.500000
# 36358 2022-06-02 22:00:00  22964.083333
# 36359 2022-06-02 23:00:00  20949.666667
#
# [36360 rows x 2 columns]
